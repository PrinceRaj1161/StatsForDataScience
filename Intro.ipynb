# %% [markdown]
# <a href="https://colab.research.google.com/github/PrinceRaj1161/StatsForDataScience/blob/main/Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Topics to Study for Stats.
# We will learn in 3 parts: -
#
#
# 1.   Basic stats
# 2.   Intermediate stats
# 3.   Advanced stats

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
